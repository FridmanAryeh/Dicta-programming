# %%
import requests
import json
import re
import collections

# %%
def strip_non_hebrew(s):
    return re.sub(r'[^א-ת ]','',s.replace('־',' '))

# %%
def find_lex(word):
    search_url= 'https://tanach-search-2-2.loadbalancer.dicta.org.il/lexemes'
    data = {
            "from": 0,
            "size": 10000,
            "query": word,
        }
    r = requests.post(search_url, json=data)
        #prnum(r.status_code)
    if r.status_code == 200:
            roots=r.json()
    
    lexemeWords = []
    lexmLen = len(roots[0]['allLexemes'])
    for m in range(lexmLen):
        lexemeWords.append(strip_non_hebrew(roots[0]['allLexemes'][m]['lexeme']))

    return(list(set(lexemeWords)))

# %%
def search(s,num,book):
    
    if book == 'tanach':
        url = 'https://tanach-search-2-2.loadbalancer.dicta.org.il/textAnalysis'
    if book == 'talmud':
        url = 'https://talmud-search.loadbalancer.dicta.org.il/textAnalysis'

    search_url= url
    data = {
        "from": 0,
        "size": num,
        "query": s,
    }
    r = requests.post(search_url, json=data)
    #prnum(r.status_code)
    if r.status_code == 200:
        r_dict=r.json()
        return(r_dict)
    else:
        return None

# %%
word = 'פיקח'
size = 200
book = 'talmud'
r_dict = search(word,size,book)

# %%
r_dict
# Out:
# [[[{'word': 'אי',
#     'lexeme': 'אִי (Conjunction) ',
#     'lexemeCode': 'אִי',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'הכי',
#     'lexeme': 'הָכִי (Adverb) ',
#     'lexemeCode': 'הָכִי',
#     'morphology': 'adv, aramaic',
#     'morphologyCode': 'fffffftfffffffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אימא',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, fut, mas, per1, aramaic',
#     'morphologyCode': 'ffffftfftffftffffffffftfffffffffffftffffffftffffffffftffffffffffffffffffffffff'},
#    {'word': 'סיפא',
#     'lexeme': 'סֵיפָא (Noun) ',
#     'lexemeCode': 'סֵיפָא/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אם',
#     'lexeme': 'אִם (Conjunction) ',
#     'lexemeCode': 'אִם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'היה',
#     'lexeme': 'היי (Verb) ',
#     'lexemeCode': 'היי[',
#     'morphology': 'sing, verb, paal, past, mas, per3',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffftfffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פיקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שוכר',
#     'lexeme': 'שׂוֹכֵר (Participle) ',
#     'lexemeCode': 'שׂוֹכֵר/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'את',
#     'lexeme': 'אֶת (Conjunction) ',
#     'lexemeCode': 'אֶת',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מקומן',
#     'lexeme': 'מָקוֹם (Noun) ',
#     'lexemeCode': 'מָקוֹם/',
#     'morphology': 'noun, sing, mas, abs, poss, fem, plural, per3',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftffffffffffffffffffttttfffffffffffffffff'},
#    {'word': 'ואי',
#     'lexeme': 'אִי (Conjunction) ',
#     'lexemeCode': 'אִי',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'ברשות',
#     'lexeme': 'רְשׁוּת (Noun) ',
#     'lexemeCode': 'רְשׁוּת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הרבים',
#     'lexeme': 'רַב (Title) ',
#     'lexemeCode': 'רַב/',
#     'morphology': 'paal, plural, mas, abs, per-any, participle',
#     'morphologyCode': 'fffffffffffftfffffftffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'ממאן',
#     'lexeme': 'מַן (Interrogative) ',
#     'lexemeCode': 'מַן/',
#     'morphology': 'interrogative, aramaic',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffffftfftffffffffffffffffffffffff'},
#    {'word': 'אגר',
#     'lexeme': 'אַגְרָא (Noun) ',
#     'lexemeCode': 'אַגְרָא/',
#     'morphology': 'noun, sing, mas, abs, aramaic',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'הכי',
#     'lexeme': 'הָכִי (Adverb) ',
#     'lexemeCode': 'הָכִי',
#     'morphology': 'adv, aramaic',
#     'morphologyCode': 'fffffftfffffffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'קאמר',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'ואם',
#     'lexeme': 'אִם (Conjunction) ',
#     'lexemeCode': 'אִם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ברשות',
#     'lexeme': 'רְשׁוּת (Noun) ',
#     'lexemeCode': 'רְשׁוּת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעלים',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'היא',
#     'lexeme': 'הוּא (Pronoun) ',
#     'lexemeCode': 'הוּא',
#     'morphology': 'pronoun, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffffffftffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אם',
#     'lexeme': 'אִם (Conjunction) ',
#     'lexemeCode': 'אִם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'היה',
#     'lexeme': 'היי (Verb) ',
#     'lexemeCode': 'היי[',
#     'morphology': 'sing, verb, paal, past, mas, per3',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffftfffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פיקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שוכר',
#     'lexeme': 'שׂוֹכֵר (Participle) ',
#     'lexemeCode': 'שׂוֹכֵר/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'את',
#     'lexeme': 'אֶת (Conjunction) ',
#     'lexemeCode': 'אֶת',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מקומן',
#     'lexeme': 'מָקוֹם (Noun) ',
#     'lexemeCode': 'מָקוֹם/',
#     'morphology': 'noun, sing, mas, abs, poss, fem, plural, per3',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftffffffffffffffffffttttfffffffffffffffff'}]],
#  [[{'word': 'שני',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'sing, num, mas, abs',
#     'morphologyCode': 'ffffftffffffffffftffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחין',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, plural, abs, masc/fem',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffftftfffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחד',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, mas, quantifier',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואחד',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, mas, quantifier',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'נשואין',
#     'lexeme': 'נָשׂוּא (Participle) ',
#     'lexemeCode': 'נָשׂוּא/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'לשתי',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'num, fem, const, dual',
#     'morphologyCode': 'ffffffffffffffffftffffffffffffffffffftftffffffftffffffffffffffffffffffffffffff'},
#    {'word': 'נכריות',
#     'lexeme': 'נׇכְרִי (Adjective) ',
#     'lexemeCode': 'נׇכְרִי/',
#     'morphology': 'plural, adj, abs',
#     'morphologyCode': 'ffffffffffffffffffftfffffffffffffftffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחות',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'plural, adj, abs',
#     'morphologyCode': 'ffffffffffffffffffftfffffffffffffftffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'חולץ',
#     'lexeme': 'חוֹלֵץ (Participle) ',
#     'lexemeCode': 'חוֹלֵץ/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מייבם',
#     'lexeme': 'יבם (Verb) ',
#     'lexemeCode': 'יבם[',
#     'morphology': 'sing, verb, present, piel, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffftfftffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'כונס',
#     'lexeme': 'כּוֹנֵס (Participle) ',
#     'lexemeCode': 'כּוֹנֵס/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואינו',
#     'lexeme': 'אֵין (Modal) ',
#     'lexemeCode': 'אֵין/',
#     'morphology': 'present, abs, per3, mas, sing, pro, copula',
#     'morphologyCode': 'ffffffffffffftfffffffffffffffffffffffftffffffffffffffffffffftfftttffftffffffff'},
#    {'word': 'מוציא',
#     'lexeme': 'מוֹצִיא (Participle) ',
#     'lexemeCode': 'מוֹצִיא/',
#     'morphology': 'sing, hifil, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftffffffffffffffffffffftffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'לעולם',
#     'lexeme': 'לְעוֹלָם (Adverb) ',
#     'lexemeCode': 'לְעוֹלָם',
#     'morphology': 'adv, abs',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffff'}]],
#  [[{'word': 'שני',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'sing, num, mas, abs',
#     'morphologyCode': 'ffffftffffffffffftffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחין',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, plural, abs, masc/fem',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffftftfffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחין',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'נשואין',
#     'lexeme': 'נָשׂוּא (Participle) ',
#     'lexemeCode': 'נָשׂוּא/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'לשתי',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'num, fem, const, dual',
#     'morphologyCode': 'ffffffffffffffffftffffffffffffffffffftftffffffftffffffffffffffffffffffffffffff'},
#    {'word': 'נכריות',
#     'lexeme': 'נׇכְרִי (Adjective) ',
#     'lexemeCode': 'נׇכְרִי/',
#     'morphology': 'plural, adj, abs',
#     'morphologyCode': 'ffffffffffffffffffftfffffffffffffftffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחת',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, num, abs-const, fem',
#     'morphologyCode': 'ffffftffffffffffftfffffffftfffffffffftffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואחת',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, num, abs-const, fem',
#     'morphologyCode': 'ffffftffffffffffftfffffffftfffffffffftffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'כונס',
#     'lexeme': 'כּוֹנֵס (Participle) ',
#     'lexemeCode': 'כּוֹנֵס/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואם',
#     'lexeme': 'אִם (Conjunction) ',
#     'lexemeCode': 'אִם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'רצה',
#     'lexeme': 'רָץ (Participle) ',
#     'lexemeCode': 'רָץ/',
#     'morphology': 'sing, paal, fem, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftffffffffffffffffffffffffttffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'להוציא',
#     'lexeme': 'יצא (Verb) ',
#     'lexemeCode': 'יצא[',
#     'morphology': 'verb, hifil, inf',
#     'morphologyCode': 'fffffffftfffffffffffffffffftffffffffffffffffffffftffffffffffffffffffffffffffff'},
#    {'word': 'יוציא',
#     'lexeme': 'יצא (Verb) ',
#     'lexemeCode': 'יצא[',
#     'morphology': 'sing, verb, fut, hifil, mas, per3',
#     'morphologyCode': 'ffffftfftffffffffffffftfffftfffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'חולץ',
#     'lexeme': 'חוֹלֵץ (Participle) ',
#     'lexemeCode': 'חוֹלֵץ/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מייבם',
#     'lexeme': 'יבם (Verb) ',
#     'lexemeCode': 'יבם[',
#     'morphology': 'sing, verb, present, piel, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffftfftffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'}]],
#  [[{'word': 'תא',
#     'lexeme': 'תָּא (Noun) ',
#     'lexemeCode': 'תָּא/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שמע',
#     'lexeme': 'שׁמע (Verb) ',
#     'lexemeCode': 'שׁמע[',
#     'morphology': 'sing, verb, paal, mas, impr, per2',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffffffffftfffffffftffffffffftfffffffffffffffffffffff'},
#    {'word': 'שני',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'sing, num, mas, abs',
#     'morphologyCode': 'ffffftffffffffffftffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחין',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, plural, abs, masc/fem',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffftftfffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחין',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'נשואין',
#     'lexeme': 'נָשׂוּא (Participle) ',
#     'lexemeCode': 'נָשׂוּא/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שתי',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'num, fem, const, dual',
#     'morphologyCode': 'ffffffffffffffffftffffffffffffffffffftftffffffftffffffffffffffffffffffffffffff'},
#    {'word': 'נכריות',
#     'lexeme': 'נׇכְרִי (Adjective) ',
#     'lexemeCode': 'נׇכְרִי/',
#     'morphology': 'plural, adj, abs',
#     'morphologyCode': 'ffffffffffffffffffftfffffffffffffftffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחת',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, num, abs-const, fem',
#     'morphologyCode': 'ffffftffffffffffftfffffffftfffffffffftffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואחת',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, num, abs-const, fem',
#     'morphologyCode': 'ffffftffffffffffftfffffffftfffffffffftffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'החרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'כונס',
#     'lexeme': 'כּוֹנֵס (Participle) ',
#     'lexemeCode': 'כּוֹנֵס/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואם',
#     'lexeme': 'אִם (Conjunction) ',
#     'lexemeCode': 'אִם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'רוצה',
#     'lexeme': 'רוֹצֶה (Participle) ',
#     'lexemeCode': 'רוֹצֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'להוציא',
#     'lexeme': 'יצא (Verb) ',
#     'lexemeCode': 'יצא[',
#     'morphology': 'verb, hifil, inf',
#     'morphologyCode': 'fffffffftfffffffffffffffffftffffffffffffffffffffftffffffffffffffffffffffffffff'},
#    {'word': 'יוציא',
#     'lexeme': 'יצא (Verb) ',
#     'lexemeCode': 'יצא[',
#     'morphology': 'sing, verb, fut, hifil, mas, per3',
#     'morphologyCode': 'ffffftfftffffffffffffftfffftfffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'חולץ',
#     'lexeme': 'חוֹלֵץ (Participle) ',
#     'lexemeCode': 'חוֹלֵץ/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'או',
#     'lexeme': 'אוֹ (Conjunction) ',
#     'lexemeCode': 'אוֹ',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מייבם',
#     'lexeme': 'יבם (Verb) ',
#     'lexemeCode': 'יבם[',
#     'morphology': 'sing, verb, present, piel, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffftfftffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'}],
#   [{'word': 'מאי',
#     'lexeme': 'מַאי (Adverb) ',
#     'lexemeCode': 'מַאי',
#     'morphology': 'adv, abs, aramaic',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'לאו',
#     'lexeme': 'לָאו (Conjunction) ',
#     'lexemeCode': 'לָאו',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מדהוא',
#     'lexeme': 'הוּא (Copula) ',
#     'lexemeCode': 'הוּא/',
#     'morphology': 'sing, present, mas, abs, per-any, copula',
#     'morphologyCode': 'ffffftffffffftffffffffffffffffffffftfftfftffffffffffffffffffffffffffftffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מעיקרא',
#     'lexeme': 'עִקָּרָא (Noun) ',
#     'lexemeCode': 'עִקָּרָא/',
#     'morphology': 'noun, sing, mas, abs, aramaic',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'היא',
#     'lexeme': 'הוּא (Pronoun) ',
#     'lexemeCode': 'הוּא',
#     'morphology': 'pronoun, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffffffftffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'נמי',
#     'lexeme': 'נָמֵי (Adverb) ',
#     'lexemeCode': 'נָמֵי',
#     'morphology': 'adv, aramaic',
#     'morphologyCode': 'fffffftfffffffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מעיקרא',
#     'lexeme': 'עִקָּרָא (Noun) ',
#     'lexemeCode': 'עִקָּרָא/',
#     'morphology': 'noun, sing, mas, abs, aramaic',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'וקתני',
#     'lexeme': 'תני (Verb) ',
#     'lexemeCode': 'תני[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'כונס',
#     'lexeme': 'כּוֹנֵס (Participle) ',
#     'lexemeCode': 'כּוֹנֵס/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אין',
#     'lexeme': 'אִין (Adjective) ',
#     'lexemeCode': 'אִין/',
#     'morphology': 'sing, adj, mas, abs',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffttfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חולץ',
#     'lexeme': 'חוֹלֵץ (Participle) ',
#     'lexemeCode': 'חוֹלֵץ/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'לא',
#     'lexeme': 'לָא (Negative) ',
#     'lexemeCode': 'לָא/',
#     'morphology': 'neg, aramaic',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffftfffftffffffffffffffffffffffff'},
#    {'word': 'מידי',
#     'lexeme': 'מִידֵי (Preposition) ',
#     'lexemeCode': 'מִידֵי',
#     'morphology': 'prep',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'איריא',
#     'lexeme': 'אִרְיָא (Noun) ',
#     'lexemeCode': 'אִרְיָא/',
#     'morphology': 'noun, sing, mas, abs, aramaic',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'הא',
#     'lexeme': 'הָא (Interjection) ',
#     'lexemeCode': 'הָא',
#     'morphology': 'interjection, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffftffffffftffffffffffffffffffffffff'},
#    {'word': 'כדאיתא',
#     'lexeme': 'אִית (Existential) ',
#     'lexemeCode': 'אִית/',
#     'morphology': 'aramaic, exist',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffffffffffftfffffffffffffffffftfffff'},
#    {'word': 'והא',
#     'lexeme': 'הָא (Interjection) ',
#     'lexemeCode': 'הָא',
#     'morphology': 'interjection, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffftffffffftffffffffffffffffffffffff'},
#    {'word': 'כדאיתא',
#     'lexeme': 'אִית (Existential) ',
#     'lexemeCode': 'אִית/',
#     'morphology': 'aramaic, exist',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffffffffffftfffffffffffffffffftfffff'}]],
#  [[{'word': 'שני',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'sing, num, mas, abs',
#     'morphologyCode': 'ffffftffffffffffftffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחין',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, plural, abs, masc/fem',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffftftfffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחד',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, mas, quantifier',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואחד',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, mas, quantifier',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'נשואין',
#     'lexeme': 'נָשׂוּא (Participle) ',
#     'lexemeCode': 'נָשׂוּא/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'לשתי',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'num, fem, const, dual',
#     'morphologyCode': 'ffffffffffffffffftffffffffffffffffffftftffffffftffffffffffffffffffffffffffffff'},
#    {'word': 'אחיות',
#     'lexeme': 'אָחוֹת (Noun) ',
#     'lexemeCode': 'אָחוֹת/',
#     'morphology': 'noun, plural, fem, abs',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחות',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'plural, adj, abs',
#     'morphologyCode': 'ffffffffffffffffffftfffffffffffffftffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הפקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הפקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'תצא',
#     'lexeme': 'יצא (Verb) ',
#     'lexemeCode': 'יצא[',
#     'morphology': 'sing, verb, paal, fut, mas, per2',
#     'morphologyCode': 'ffffftfftffftffffffffftfffffffffffftfffffffffffffffffftfffffffffffffffffffffff'},
#    {'word': 'משום',
#     'lexeme': 'מִשּׁוּם (Conjunction) ',
#     'lexemeCode': 'מִשּׁוּם',
#     'morphology': 'conj',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחות',
#     'lexeme': 'אָחוֹת (Noun) ',
#     'lexemeCode': 'אָחוֹת/',
#     'morphology': 'noun, sing, fem, const',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffffftftffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אשה',
#     'lexeme': 'אִשָּׁה (Noun) ',
#     'lexemeCode': 'אִשָּׁה/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'}],
#   [{'word': 'מת',
#     'lexeme': 'מֵת (Participle) ',
#     'lexemeCode': 'מֵת/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הפקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מה',
#     'lexeme': 'מָה (Quantifier) ',
#     'lexemeCode': 'מָה/',
#     'morphology': 'const, quantifier',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffffffffffffftffff'},
#    {'word': 'יעשה',
#     'lexeme': 'עשׂי (Verb) ',
#     'lexemeCode': 'עשׂי[',
#     'morphology': 'sing, verb, paal, fut, mas, per3',
#     'morphologyCode': 'ffffftfftffftffffffffftffffffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרש',
#     'lexeme': 'חֵרֵשׁ (Noun) ',
#     'lexemeCode': 'חֵרֵשׁ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחת',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'sing, adj, fem, abs',
#     'morphologyCode': 'ffffftfffffffffffffffffffffffffffftffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מוציא',
#     'lexeme': 'מוֹצִיא (Participle) ',
#     'lexemeCode': 'מוֹצִיא/',
#     'morphology': 'sing, hifil, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftffffffffffffffffffffftffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אשתו',
#     'lexeme': 'אִשָּׁה (Noun) ',
#     'lexemeCode': 'אִשָּׁה/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בגט',
#     'lexeme': 'גֵּט (Noun) ',
#     'lexemeCode': 'גֵּט/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואשת',
#     'lexeme': 'אִשָּׁה (Noun) ',
#     'lexemeCode': 'אִשָּׁה/',
#     'morphology': 'noun, sing, fem, const',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffffftftffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחיו',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, sing, abs, masc/fem, poss, per3, mas, sing',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffftftfffffffffffffffftfftffttfffffffffffff'},
#    {'word': 'אסורה',
#     'lexeme': 'אָסוּר (Participle) ',
#     'lexemeCode': 'אָסוּר/',
#     'morphology': 'sing, paal, fem, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftffffffffffffffffffffffffttffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'לעולם',
#     'lexeme': 'לְעוֹלָם (Adverb) ',
#     'lexemeCode': 'לְעוֹלָם',
#     'morphology': 'adv, abs',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffff'}]],
#  [[{'word': 'שני',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'sing, num, mas, abs',
#     'morphologyCode': 'ffffftffffffffffftffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחין',
#     'lexeme': 'אָח (Noun) ',
#     'lexemeCode': 'אָח/',
#     'morphology': 'noun, plural, abs, masc/fem',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffftftfffffffffffffffffffffffffffffffffffff'},
#    {'word': 'פקחין',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'נשואין',
#     'lexeme': 'נָשׂוּא (Participle) ',
#     'lexemeCode': 'נָשׂוּא/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'לשתי',
#     'lexeme': 'שְׁנַיִם (Number) ',
#     'lexemeCode': 'שְׁנַיִם/',
#     'morphology': 'num, fem, const, dual',
#     'morphologyCode': 'ffffffffffffffffftffffffffffffffffffftftffffffftffffffffffffffffffffffffffffff'},
#    {'word': 'אחיות',
#     'lexeme': 'אָחוֹת (Noun) ',
#     'lexemeCode': 'אָחוֹת/',
#     'morphology': 'noun, plural, fem, abs',
#     'morphologyCode': 'fffftfffffffffffffftfffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אחת',
#     'lexeme': 'אֶחָד (Quantifier) ',
#     'lexemeCode': 'אֶחָד/',
#     'morphology': 'sing, num, abs-const, fem',
#     'morphologyCode': 'ffffftffffffffffftfffffffftfffffffffftffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חרשת',
#     'lexeme': 'חֵרֶשֶׁת (Noun) ',
#     'lexemeCode': 'חֵרֶשֶׁת/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ואחת',
# ...
#     'morphology': 'noun, plural, mas, abs, aramaic',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'דיתמי',
#     'lexeme': 'יתם (Verb) ',
#     'lexemeCode': 'יתם[',
#     'morphology': 'verb, paal, inf, sing, per1, acc/nom, masc/fem',
#     'morphologyCode': 'fffffffftffftfffffffffffffffffffffffffffffffffffftfffffffffffffftffttffffftfff'},
#    {'word': 'לבעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חוב',
#     'lexeme': 'חוֹב (Noun) ',
#     'lexemeCode': 'חוֹב/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'לא',
#     'lexeme': 'לָא (Negative) ',
#     'lexemeCode': 'לָא/',
#     'morphology': 'neg, aramaic',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffftfffftffffffffffffffffffffffff'},
#    {'word': 'משתעבדי',
#     'lexeme': 'שׁעבד (Verb) ',
#     'lexemeCode': 'שׁעבד[',
#     'morphology': 'sing, verb, present, hitpael, mas, per-any, sing, pro, per1, masc/fem',
#     'morphologyCode': 'ffffftfftfffftfffffffffffffffftfffftffffftffffffffffffffffffffffttftfffffftfff'}],
#   [{'word': 'ואמר',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'רבא',
#     'lexeme': 'רָבָא (Name) ',
#     'lexemeCode': 'רָבָא/',
#     'morphology': 'name, mas',
#     'morphologyCode': 'fffffffffffffffffffffffffffftfffffftffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אי',
#     'lexeme': 'אִי (Conjunction) ',
#     'lexemeCode': 'אִי',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'פיקח',
#     'lexeme': 'פִּקֵּחַ (Noun) ',
#     'lexemeCode': 'פִּקֵּחַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שמעון',
#     'lexeme': 'שִׁמְעוֹן (Name) ',
#     'lexemeCode': 'שִׁמְעוֹן/',
#     'morphology': 'name',
#     'morphologyCode': 'fffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מגבי',
#     'lexeme': 'גבי (Verb) ',
#     'lexemeCode': 'גבי[',
#     'morphology': 'sing, verb, present, hifil, mas, per-any, sing, pro, per1, masc/fem',
#     'morphologyCode': 'ffffftfftfffftffffffffffffftffffffftffffftffffffffffffffffffffffttftfffffftfff'},
#    {'word': 'להו',
#     'lexeme': 'להי (Verb) ',
#     'lexemeCode': 'להי[',
#     'morphology': 'verb, paal, plural, mas, impr, per2',
#     'morphologyCode': 'fffffffftffftfffffftffffffffffffffftfffffffftffffffffftfffffffffffffffffffffff'},
#    {'word': 'ארעא',
#     'lexeme': 'אַרְעָא (Noun) ',
#     'lexemeCode': 'אַרְעָא/',
#     'morphology': 'noun, sing, fem, abs, aramaic',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'והדר',
#     'lexeme': 'הדר (Verb) ',
#     'lexemeCode': 'הדר[',
#     'morphology': 'sing, verb, paal, past, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffftfffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'גבי',
#     'lexeme': 'גבי (Verb) ',
#     'lexemeCode': 'גבי[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'לה',
#     'lexeme': 'לְ (Preposition) ',
#     'lexemeCode': 'לְ',
#     'morphology': 'prep, fem, per3, sing, pro',
#     'morphologyCode': 'ffffffffffftfffffffffffffffffffffffffffffffffffffffffffffftftfffttffffffffffff'},
#    {'word': 'מינייהו',
#     'lexeme': 'מִן (Preposition) ',
#     'lexemeCode': 'מִן',
#     'morphology': 'prep, aramaic',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'דאמר',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, past, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffftfffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'רב',
#     'lexeme': 'רַב (Title) ',
#     'lexemeCode': 'רַב/',
#     'morphology': 'sing, mas, titular',
#     'morphologyCode': 'ffffftffffffffffffffffffffffffffffftffffffffffffffffffffffffftffffffffffffffff'},
#    {'word': 'נחמן',
#     'lexeme': 'נַחְמָן (Name) ',
#     'lexemeCode': 'נַחְמָן/',
#     'morphology': 'name',
#     'morphologyCode': 'fffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'יתומים',
#     'lexeme': 'יָתוֹם (Noun) ',
#     'lexemeCode': 'יָתוֹם/',
#     'morphology': 'noun, plural, mas, abs',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'שגבו',
#     'lexeme': 'גָּבֵינָא (Participle) ',
#     'lexemeCode': 'גָּבֵינָא/',
#     'morphology': 'paal, plural, mas, per3, abs, participle, aramaic',
#     'morphologyCode': 'fffffffffffftfffffftfffffffffffffffttftffftfffffffffftffffffffffffffffffffffff'},
#    {'word': 'קרקע',
#     'lexeme': 'קַרְקַע (Noun) ',
#     'lexemeCode': 'קַרְקַע/',
#     'morphology': 'noun, sing, fem, abs',
#     'morphologyCode': 'ffffttfffffffffffffffffffffffffffffffttfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'בחובת',
#     'lexeme': 'חוֹבָה (Noun) ',
#     'lexemeCode': 'חוֹבָה/',
#     'morphology': 'noun, sing, fem, const',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffffftftffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'אביהם',
#     'lexeme': 'אָב (Noun) ',
#     'lexemeCode': 'אָב/',
#     'morphology': 'noun, sing, mas, abs, poss, plural, per3, mas',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffftfttfftffffffffffffff'},
#    {'word': 'בעל',
#     'lexeme': 'בַּעַל (Noun) ',
#     'lexemeCode': 'בַּעַל/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חוב',
#     'lexeme': 'חוֹב (Noun) ',
#     'lexemeCode': 'חוֹב/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'חוזר',
#     'lexeme': 'חוֹזֵר (Participle) ',
#     'lexemeCode': 'חוֹזֵר/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'וגובה',
#     'lexeme': 'גּוֹבֶה (Participle) ',
#     'lexemeCode': 'גּוֹבֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אותה',
#     'lexeme': 'אֵת (Preposition) ',
#     'lexemeCode': 'אֵת',
#     'morphology': 'prep',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מהן',
#     'lexeme': 'מִן (Preposition) ',
#     'lexemeCode': 'מִן',
#     'morphology': 'prep, fem, plural, per3, pro',
#     'morphologyCode': 'ffffffffffftfffffffffffffffffffffffffffffffffffffffffffffftttfffftffffffffffff'}],
#   [{'word': 'אי',
#     'lexeme': 'אִי (Conjunction) ',
#     'lexemeCode': 'אִי',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אמרת',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, present, mas, aramaic, per2',
#     'morphologyCode': 'ffffftfftfffttffffffffffffffffffffftfffffffffffffffffttfffffffffffffffffffffff'},
#    {'word': 'בשלמא',
#     'lexeme': 'בִּשְׁלָמָא (Adverb) ',
#     'lexemeCode': 'בִּשְׁלָמָא',
#     'morphology': 'adv, abs, aramaic',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'למפרע',
#     'lexeme': 'מַפְרֵעַ (Noun) ',
#     'lexemeCode': 'מַפְרֵעַ/',
#     'morphology': 'noun, sing, mas, abs',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הוא',
#     'lexeme': 'הוּא (Pronoun) ',
#     'lexemeCode': 'הוּא',
#     'morphology': 'sing, pronoun, mas, per3',
#     'morphologyCode': 'ffffftffffffffffffffffffftfffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'גובה',
#     'lexeme': 'גּוֹבֶה (Participle) ',
#     'lexemeCode': 'גּוֹבֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אמטו',
#     'lexeme': 'אַמְּטוּ (Preposition) ',
#     'lexemeCode': 'אַמְּטוּ',
#     'morphology': 'prep, aramaic',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'להכי',
#     'lexeme': 'הָכִי (Adverb) ',
#     'lexemeCode': 'הָכִי',
#     'morphology': 'adv, aramaic',
#     'morphologyCode': 'fffffftfffffffffffffffffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'חוזר',
#     'lexeme': 'חוֹזֵר (Participle) ',
#     'lexemeCode': 'חוֹזֵר/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'וגובה',
#     'lexeme': 'גּוֹבֶה (Participle) ',
#     'lexemeCode': 'גּוֹבֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אותה',
#     'lexeme': 'אֵת (Preposition) ',
#     'lexemeCode': 'אֵת',
#     'morphology': 'prep',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מהן',
#     'lexeme': 'מִן (Preposition) ',
#     'lexemeCode': 'מִן',
#     'morphology': 'prep, fem, plural, per3, pro',
#     'morphologyCode': 'ffffffffffftfffffffffffffffffffffffffffffffffffffffffffffftttfffftffffffffffff'},
#    {'word': 'דכמאן',
#     'lexeme': 'מַן (Interrogative) ',
#     'lexemeCode': 'מַן/',
#     'morphology': 'interrogative, aramaic',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffffftfftffffffffffffffffffffffff'},
#    {'word': 'דגבו',
#     'lexeme': 'גבי (Verb) ',
#     'lexemeCode': 'גבי[',
#     'morphology': 'verb, paal, present, plural, mas, per3, aramaic',
#     'morphologyCode': 'fffffffftfffttffffftfffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'מחיים',
#     'lexeme': 'חַיִּים (Name) ',
#     'lexemeCode': 'חַיִּים/',
#     'morphology': 'name',
#     'morphologyCode': 'fffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'דאבוהון',
#     'lexeme': 'בֹּהוּ (Noun) ',
#     'lexemeCode': 'בֹּהוּ/',
#     'morphology': 'noun, sing, mas, abs, poss, fem, plural, per3',
#     'morphologyCode': 'ffffttffffffffffffffffffffffffffffftfftffffffffffffffffffttttfffffffffffffffff'},
#    {'word': 'דמי',
#     'lexeme': 'דמי (Verb) ',
#     'lexemeCode': 'דמי[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אלא',
#     'lexeme': 'אֶלָּא (Conjunction) ',
#     'lexemeCode': 'אֶלָּא',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אי',
#     'lexeme': 'אִי (Conjunction) ',
#     'lexemeCode': 'אִי',
#     'morphology': 'conj, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffftffffffffffffffffffffffffffffffftffffffffffffffffffffffff'},
#    {'word': 'אמרת',
#     'lexeme': 'אמר (Verb) ',
#     'lexemeCode': 'אמר[',
#     'morphology': 'sing, verb, paal, present, mas, aramaic, per2',
#     'morphologyCode': 'ffffftfftfffttffffffffffffffffffffftfffffffffffffffffttfffffffffffffffffffffff'},
#    {'word': 'מכאן',
#     'lexeme': 'מִכָּאן (Adverb) ',
#     'lexemeCode': 'מִכָּאן',
#     'morphology': 'adv, abs',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'ולהבא',
#     'lexeme': 'לְהַבָּא (Adverb) ',
#     'lexemeCode': 'לְהַבָּא',
#     'morphology': 'adv, abs',
#     'morphologyCode': 'fffffftffffffffffffffffffffffffffffffftfffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'הוא',
#     'lexeme': 'הוּא (Pronoun) ',
#     'lexemeCode': 'הוּא',
#     'morphology': 'sing, pronoun, mas, per3',
#     'morphologyCode': 'ffffftffffffffffffffffffftfffffffffttfffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'גובה',
#     'lexeme': 'גּוֹבֶה (Participle) ',
#     'lexemeCode': 'גּוֹבֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אמאי',
#     'lexeme': 'מַאי (Interrogative) ',
#     'lexemeCode': 'מַאי/',
#     'morphology': 'interrogative',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffffftfffffffffffffffffffffffffff'},
#    {'word': 'חוזר',
#     'lexeme': 'חוֹזֵר (Participle) ',
#     'lexemeCode': 'חוֹזֵר/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'וגובה',
#     'lexeme': 'גּוֹבֶה (Participle) ',
#     'lexemeCode': 'גּוֹבֶה/',
#     'morphology': 'sing, paal, mas, abs, per-any, participle',
#     'morphologyCode': 'ffffftfffffftfffffffffffffffffffffftfftffttfffffffffffffffffffffffffffffffffff'},
#    {'word': 'אותה',
#     'lexeme': 'אֵת (Preposition) ',
#     'lexemeCode': 'אֵת',
#     'morphology': 'prep',
#     'morphologyCode': 'ffffffffffftffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'מהן',
#     'lexeme': 'מִן (Preposition) ',
#     'lexemeCode': 'מִן',
#     'morphology': 'prep, fem, plural, per3, pro',
#     'morphologyCode': 'ffffffffffftfffffffffffffffffffffffffffffffffffffffffffffftttfffftffffffffffff'},
#    {'word': 'הא',
#     'lexeme': 'הָא (Interjection) ',
#     'lexemeCode': 'הָא',
#     'morphology': 'interjection, aramaic',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffftffffffftffffffffffffffffffffffff'},
#    {'word': 'הוי',
#     'lexeme': 'הֲוָה (Copula) ',
#     'lexemeCode': 'הֲוָה/',
#     'morphology': 'aramaic, copula',
#     'morphologyCode': 'ffffffffffffffffffffffffffffffffffffffffffffffffffffftffffffffffffffftffffffff'},
#    {'word': 'כמאן',
#     'lexeme': 'מַן (Interrogative) ',
#     'lexemeCode': 'מַן/',
#     'morphology': 'interrogative, aramaic',
#     'morphologyCode': 'fffffffffffffffffffffffffffffffffffffffffffffffffftfftffffffffffffffffffffffff'},
#    {'word': 'דזבין',
#     'lexeme': 'זְבִינְנָא (Participle) ',
#     'lexemeCode': 'זְבִינְנָא/',
#     'morphology': 'sing, paal, mas, per3, abs, participle, aramaic',
#     'morphologyCode': 'ffffftfffffftffffffffffffffffffffffttftffftfffffffffftffffffffffffffffffffffff'},
#    {'word': 'יתמי',
#     'lexeme': 'יתם (Verb) ',
#     'lexemeCode': 'יתם[',
#     'morphology': 'sing, verb, paal, fem, impr, per2',
#     'morphologyCode': 'ffffftfftffftfffffffffffffffffffffffftfffffftffffffffftfffffffffffffffffffffff'},
#    {'word': 'נכסי',
#     'lexeme': 'נֶכֶס (Noun) ',
#     'lexemeCode': 'נֶכֶס/',
#     'morphology': 'noun, plural, mas, const',
#     'morphologyCode': 'fffftfffffffffffffftffffffffffffffftffftffffffffffffffffffffffffffffffffffffff'},
#    {'word': 'דמי',
#     'lexeme': 'דמי (Verb) ',
#     'lexemeCode': 'דמי[',
#     'morphology': 'sing, verb, paal, present, mas, per3, aramaic',
#     'morphologyCode': 'ffffftfftfffttfffffffffffffffffffffttfffffffffffffffftffffffffffffffffffffffff'}]]]

# %%
def get_wordforms(str):
    query=str
    r_wordforms = requests.post(
        'https://talmud-search.loadbalancer.dicta.org.il/wordforms',
        json={
            "query": query
        }
    )
    print(r_wordforms.status_code)

    if (r_wordforms.status_code==200):
        r_wordforms_dict=r_wordforms.json()
        
    a = r_wordforms_dict[0]['wordForms']
    words = {}
    for x in range(len(a)):
        words[x]=a[x]['wordForm']
    justwords = [ v for v in words.values() ]
    clean_justwords = {}
    for j in range(len(justwords)):
        clean_justwords[j]=strip_non_hebrew(justwords[j])
    clean_justwords = [ v for v in clean_justwords.values() ]
    return(clean_justwords)

# %%
def top_words_lex(word,size,book):
    list_of_words = []
    r_dict = search(word,size,book)
    results = len(r_dict)
    stop_words = ['את','אל','כי','על','עם','לא','ואת','ויהי','ולא','עד','לך','לפני','לי','שם','אתה','הזה','הוא','אם','גם','מה','לו','היה','או','מאי','אי','הכי','אמר','רב','רבי','הא','נמי','מי','הרי','זה','היי','כל','של','בן','ל']
    word_forms = get_wordforms(word)
    
    for i in range(results):  #for each result
        if i == 0:
            big_count = collections.Counter()
        list_of_wordslex = []
        for j in range(len(r_dict[i])): #if there are more than one "mini result" in result
            for k in range(len(r_dict[i][j])):
                word = (r_dict[i][j][k])
                lex = word['lexeme']
                lexCode = strip_non_hebrew(word['lexemeCode'])
                if lexCode not in stop_words:
                    if lexCode not in word_forms:
                        list_of_wordslex.append(lex)
                
        small_count = collections.Counter(list_of_wordslex)
        big_count = big_count + small_count
    top_lexeme = (list(big_count.most_common()[0]))[0]
    
    list_of_tops = []
    
    for a in range(results):
        for b in range(len(r_dict[a])):
            for c in range(len(r_dict[a][b])):
                if r_dict[a][b][c]['lexeme'] == top_lexeme:
                    list_of_tops.append(r_dict[a][b][c]['word'])
    
    list_of_tops = list(set(list_of_tops))           
    
        
        
    # added word
        
        
        
    return(big_count.most_common()[0],list_of_tops)

# %%
word = 'פיקח'
size = 200
book = 'talmud'
top_words_lex(word,size,book)
# Out:
# 200
# (('חֵרֵשׁ (Noun) ', 104),
#  ['לחרש', 'חרשין', 'וחרש', 'חרש', 'אחרשין', 'החרש', 'חֵרֵשׁ', 'מחרש', 'בחרש'])
